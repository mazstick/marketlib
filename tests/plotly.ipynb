# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd
from marketlib import Market

df = pd.read_csv("BTCUSDT15m.csv")
btc = Market(df, "BTCUSDT", "15m")
btc.to_dataframe()
# Out:
#                                 open       high        low      close   volume
# datetime
# 2025-07-31 01:00:00+03:30  117061.00  117159.42  117014.84  117099.99   9.2609
# 2025-07-31 01:15:00+03:30  117100.00  117365.00  117100.00  117359.58  20.4767
# 2025-07-31 01:30:00+03:30  117359.57  117462.71  117296.58  117395.31  21.1849
# 2025-07-31 01:45:00+03:30  117395.31  117457.18  117304.39  117345.62   6.9827
# 2025-07-31 02:00:00+03:30  117345.63  117464.75  117319.95  117459.99   8.8303
# ...                              ...        ...        ...        ...      ...
# 2025-08-10 09:45:00+03:30  118011.66  118011.66  117831.00  117848.38  19.0433
# 2025-08-10 10:00:00+03:30  117848.38  117973.67  117741.62  117973.67  19.2846
# 2025-08-10 10:15:00+03:30  117973.67  118124.00  117919.66  118069.35  17.0271
# 2025-08-10 10:30:00+03:30  118069.35  118234.00  118058.26  118140.70  18.2094
# 2025-08-10 10:45:00+03:30  118140.69  118147.24  118086.81  118146.66   4.1656
#
# ...

# %%
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, vertical_spacing=0.5)
fig.add_trace(
    go.Candlestick(
        x=btc.to_dataframe().index,
        close=btc.get_closes(),
        open=btc.get_opens(),
        high=btc.get_highs(),
        low=btc.get_lows(),
        increasing=go.candlestick.Increasing(fillcolor="rgb(0,200,0)"),
        decreasing=go.candlestick.Decreasing(fillcolor="rgb(200,0,0)"),
    )
)

fig.update_layout()

fig.show()

# %%
from marketlib.plotly import Plotly
from marketlib.indicators import *
sma = SMA(btc.to_dataframe(), [14, 60])
plotly = Plotly()
plotly.add_chart(btc.to_dataframe(), btc.symbol, btc.timeframe)
plotly.add_indicators(sma)
plotly.plot()
# Out:
# 0
# 1
